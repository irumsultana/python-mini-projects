# %% [markdown]
# <a href="https://colab.research.google.com/github/irumsultana/python-mini-projects/blob/main/python_mini_projects.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#CHECKING ELIGIBILITY:

age = int(input("Enter your age: "))
if age>=18:
    print("You are eligible to vote.")
else:
    print("You are not eligible to vote.")

# %%
#TABLE:

n=int(input("Enter a number:"))
for i in range(1, 11):
    print(n*i)

# %%
#FINDING LARGEST NUMBER:

my_list = [7, 4, 1, 17, 2]
largest_number = my_list[0]

for num in my_list:
    if num > largest_number:
        largest_number = num

print(largest_number)

# %%
#FINDING SECOND LARGEST NUMBER:
a=[]
n=int(input("Enter number of elements:"))
for i in range(1,n+1):
    b=int(input("Enter element :"))
    a.append(b)
a.sort()
print("Second largest element is:",a[n-2])

# %%
#FINDING LCM:

def find_lcm(a, b):

    max_num = max(a, b)
    while True:
        if max_num % a == 0 and max_num % b == 0:
            return max_num
        max_num += 1
num1 = int(input("Enter the first number: "))
num2 = int(input("Enter the second number: "))
print("LCM:", find_lcm(num1, num2))

# %%
#PRIME FACTORS:

def find_prime_factors(n):
    factors = []
    i = 2
    while i * i <= n:
        if n % i:
            i += 1
        else:
            n //= i
            factors.append(i)
    if n > 1:
        factors.append(n)
    return factors

num = int(input("Enter a number: "))
print("Prime factors:", find_prime_factors(num))

# %%
#CHECKING PANGRAM:

def check_pangram(s):
    alphabet = "abcdefghijklmnopqrstuvwxyz"
    for char in alphabet:
        if char not in s.lower():
            return False
    return True

sentence = input("Enter a sentence: ")
if check_pangram(sentence):
    print("The sentence is a pangram.")
else:
    print("The sentence is not a pangram.")

# %%
#COUNTING CHARACTERS:

from collections import Counter
test_str = "two cows"
x = Counter(test_str)
print("Count of all characters in two cows is :\n "
      + str(x))

# %%
#WORD COUNTER:

def count_words(sentence):
    return len(sentence.split())

sentence = input("Enter a sentence: ")
print("Number of words:", count_words(sentence))
